# %% [markdown]
# # Structure recovery cases

# %%
from molop.io import AutoParser
from rdkit.Chem.Draw import IPythonConsole

IPythonConsole.drawOptions.addAtomIndices = True
IPythonConsole.molSize = 400, 400

# %% [markdown]
# ## molecule_0.log

# %%
test_file = AutoParser(
    "../../tests/test_files/g16log/molecule_0.log",
    n_jobs=1,
    only_extract_structure=True,
    only_last_frame=True,
)
test_file[0][-1].rdmol
# Out:
# MolOP parsing with single thread: 100%|██████████| 1/1 [00:00<00:00, 678.14it/s]
# 0 files failed to parse, 1 successfully parsed

# %% [markdown]
# ## dsgdb9nsd_131941-4+.log

# %%
test_file = AutoParser(
    "../../tests/test_files/g16log/dsgdb9nsd_131941-4+.log",
    n_jobs=1,
    only_extract_structure=True,
    only_last_frame=True,
)
test_file[0][-1].rdmol
# Out:
# MolOP parsing with single thread: 100%|██████████| 1/1 [00:00<00:00, 88.40it/s]
# 0 files failed to parse, 1 successfully parsed

# %%
test_file[0][-1].rdmol_no_conformer

# %% [markdown]
# ## RE_BOX-Anion-Real_Cu-III-Phenol_Major-Amide-Anion_From-IP_C-O-190_TS_Opt.log

# %%
test_file = AutoParser(
    "../../tests/test_files/g16log/RE_BOX-Anion-Real_Cu-III-Phenol_Major-Amide-Anion_From-IP_C-O-190_TS_Opt.log",
    n_jobs=1,
    only_extract_structure=True,
    only_last_frame=True,
)
test_file[0][-1].rdmol
# Out:
# MolOP parsing with single thread: 100%|██████████| 1/1 [00:00<00:00, 33.56it/s]
# 0 files failed to parse, 1 successfully parsed

# %% [markdown]
# ## add_1.fchk

# %%
test_file = AutoParser(
    "../../tests/test_files/g16fchk/add_1.fchk",
    n_jobs=1,
    only_extract_structure=True,
    only_last_frame=True,
)
test_file[0][-1].rdmol
# Out:
# MolOP parsing with single thread: 100%|██████████| 1/1 [00:00<00:00, 11.28it/s]
# 0 files failed to parse, 1 successfully parsed

# %% [markdown]
# ## add_0.fchk

# %%
test_file = AutoParser(
    "../../tests/test_files/g16fchk/add_0.fchk",
    n_jobs=1,
    only_extract_structure=True,
    only_last_frame=True,
)
test_file[0][-1].rdmol
# Out:
# MolOP parsing with single thread: 100%|██████████| 1/1 [00:00<00:00, 149.40it/s]
# 0 files failed to parse, 1 successfully parsed

# %% [markdown]
# ## dsgdb9nsd_000007-6.fchk

# %%
test_file = AutoParser(
    "../../tests/test_files/g16fchk/dsgdb9nsd_000007-6.fchk",
    n_jobs=1,
    only_extract_structure=True,
    only_last_frame=True,
)
test_file[0][-1].rdmol
# Out:
# MolOP parsing with single thread: 100%|██████████| 1/1 [00:00<00:00, 487.14it/s]
# 0 files failed to parse, 1 successfully parsed

# %% [markdown]
# ## dsgdb9nsd_000001-3.fchk

# %%
test_file = AutoParser(
    "../../tests/test_files/g16fchk/dsgdb9nsd_000001-3.fchk",
    n_jobs=1,
    only_extract_structure=True,
    only_last_frame=True,
)
test_file[0][-1].rdmol
# Out:
# MolOP parsing with single thread: 100%|██████████| 1/1 [00:00<00:00, 1434.93it/s]
# 0 files failed to parse, 1 successfully parsed

# %% [markdown]
# ## dsgdb9nsd_000484-1+.log

# %%
test_file = AutoParser(
    "../../tests/test_files/g16log/dsgdb9nsd_000484-1+.log",
    n_jobs=1,
    only_extract_structure=True,
    only_last_frame=True,
)
test_file[0][-1].rdmol
# Out:
# MolOP parsing with single thread: 100%|██████████| 1/1 [00:00<00:00, 111.55it/s]
# 0 files failed to parse, 1 successfully parsed

# %% [markdown]
# ## dsgdb9nsd_000672-3+.log

# %%
test_file = AutoParser(
    "../../tests/test_files/g16log/dsgdb9nsd_000672-3+.log",
    n_jobs=1,
    only_extract_structure=True,
    only_last_frame=True,
)
test_file[0][-1].rdmol
# Out:
# MolOP parsing with single thread: 100%|██████████| 1/1 [00:00<00:00, 122.08it/s]
# 0 files failed to parse, 1 successfully parsed

# %% [markdown]
# ## dsgdb9nsd_000923-3+.log

# %%
test_file = AutoParser(
    "../../tests/test_files/g16log/dsgdb9nsd_000923-3+.log",
    n_jobs=1,
    only_extract_structure=True,
    only_last_frame=True,
)
test_file[0][-1].rdmol
# Out:
# MolOP parsing with single thread: 100%|██████████| 1/1 [00:00<00:00, 122.06it/s]
# 0 files failed to parse, 1 successfully parsed

# %% [markdown]
# ## dsgdb9nsd_003051-3.log

# %%
test_file = AutoParser(
    "../../tests/test_files/g16log/dsgdb9nsd_003051-3.log",
    n_jobs=1,
    only_extract_structure=True,
    only_last_frame=True,
)
test_file[0][-1].rdmol
# Out:
# MolOP parsing with single thread: 100%|██████████| 1/1 [00:00<00:00, 68.66it/s]
# 0 files failed to parse, 1 successfully parsed

# %% [markdown]
# ## dsgdb9nsd_000696-4.log

# %%
test_file = AutoParser(
    "../../tests/test_files/g16log/dsgdb9nsd_000696-4.log",
    n_jobs=1,
    only_extract_structure=True,
    only_last_frame=True,
)
test_file[0][-1].rdmol
# Out:
# MolOP parsing with single thread: 100%|██████████| 1/1 [00:00<00:00, 68.17it/s]
# 0 files failed to parse, 1 successfully parsed

# %% [markdown]
# ## dsgdb9nsd_004669-4.log

# %%
test_file = AutoParser(
    "../../tests/test_files/g16log/dsgdb9nsd_004669-4.log",
    n_jobs=1,
    only_extract_structure=True,
    only_last_frame=True,
)
test_file[0][-1].rdmol
# Out:
# MolOP parsing with single thread: 100%|██████████| 1/1 [00:00<00:00, 63.29it/s]
# 0 files failed to parse, 1 successfully parsed

# %% [markdown]
# ## dsgdb9nsd_131200-4-.log

# %%
test_file = AutoParser(
    "../../tests/test_files/g16log/dsgdb9nsd_131200-4-.log",
    n_jobs=1,
    only_extract_structure=True,
    only_last_frame=True,
)
test_file[0][-1].rdmol
# Out:
# MolOP parsing with single thread: 100%|██████████| 1/1 [00:00<00:00, 94.81it/s]
# 0 files failed to parse, 1 successfully parsed

# %% [markdown]
# ## dsgdb9nsd_000955-3.log

# %%
test_file = AutoParser(
    "../../tests/test_files/g16log/dsgdb9nsd_000955-3.log",
    n_jobs=1,
    only_extract_structure=True,
    only_last_frame=True,
)
test_file[0][-1].rdmol
# Out:
# MolOP parsing with single thread: 100%|██████████| 1/1 [00:00<00:00, 67.20it/s]
# 0 files failed to parse, 1 successfully parsed

# %%
test_file[0][-1].rdmol_no_conformer

# %% [markdown]
# ## r1_C2H3N3O_sp_g16.log

# %%
test_file = AutoParser(
    "../../tests/test_files/g16log/r1_C2H3N3O_sp_g16.log",
    n_jobs=1,
    only_extract_structure=True,
    only_last_frame=True,
)
test_file[0][-1].rdmol
# Out:
# MolOP parsing with single thread: 100%|██████████| 1/1 [00:00<00:00, 1385.63it/s]
# 0 files failed to parse, 1 successfully parsed

# %% [markdown]
# ## r1_C8H9N3O2_sp_g16.log

# %%
test_file = AutoParser(
    "../../tests/test_files/g16log/r1_C8H9N3O2_sp_g16.log",
    n_jobs=1,
    only_extract_structure=True,
    only_last_frame=True,
)
test_file[0][-1].rdmol
# Out:
# MolOP parsing with single thread: 100%|██████████| 1/1 [00:00<00:00, 920.21it/s]
# 0 files failed to parse, 1 successfully parsed

# %% [markdown]
# ## dsgdb9nsd_004738-2.log

# %%
test_file = AutoParser(
    "../../tests/test_files/g16log/dsgdb9nsd_004738-2.log",
    n_jobs=1,
    only_extract_structure=True,
    only_last_frame=True,
)
test_file[0][-1].rdmol
# Out:
# MolOP parsing with single thread: 100%|██████████| 1/1 [00:00<00:00, 63.53it/s]
# 0 files failed to parse, 1 successfully parsed

# %% [markdown]
# ## dsgdb9nsd_004015-3-.log

# %%
test_file = AutoParser(
    "../../tests/test_files/g16log/dsgdb9nsd_004015-3-.log",
    n_jobs=1,
    only_extract_structure=True,
    only_last_frame=True,
)
test_file[0][-1].rdmol
# Out:
# MolOP parsing with single thread: 100%|██████████| 1/1 [00:00<00:00, 103.04it/s]
# 0 files failed to parse, 1 successfully parsed

# %% [markdown]
# ## dsgdb9nsd_000107-3-.log

# %%
test_file = AutoParser(
    "../../tests/test_files/g16log/dsgdb9nsd_000107-3-.log",
    n_jobs=1,
    only_extract_structure=True,
    only_last_frame=True,
)
test_file[0][-1].rdmol
# Out:
# MolOP parsing with single thread: 100%|██████████| 1/1 [00:00<00:00, 163.86it/s]
# 0 files failed to parse, 1 successfully parsed

# %% [markdown]
# ## dsgdb9nsd_004517-4-.log

# %%
test_file = AutoParser(
    "../../tests/test_files/g16log/dsgdb9nsd_004478-6-.log",
    n_jobs=1,
    only_extract_structure=True,
    only_last_frame=True,
)
test_file[0][-1].rdmol
# Out:
# MolOP parsing with single thread: 100%|██████████| 1/1 [00:00<00:00, 106.90it/s]
# 0 files failed to parse, 1 successfully parsed

# %%
test_file[0][-1].rdmol_no_conformer

# %% [markdown]
# ## dsgdb9nsd_004517-4-.log

# %%
test_file = AutoParser(
    "../../tests/test_files/g16log/dsgdb9nsd_004517-4-.log",
    n_jobs=1,
    only_extract_structure=True,
    only_last_frame=True,
)
test_file[0][-1].rdmol
# Out:
# MolOP parsing with single thread: 100%|██████████| 1/1 [00:00<00:00, 108.15it/s]
# 0 files failed to parse, 1 successfully parsed

# %% [markdown]
# ## dsgdb9nsd_000958-3-.log

# %%
test_file = AutoParser(
    "../../tests/test_files/g16log/dsgdb9nsd_000958-3-.log",
    n_jobs=1,
    only_extract_structure=True,
    only_last_frame=True,
)
test_file[0][-1].rdmol
# Out:
# MolOP parsing with single thread: 100%|██████████| 1/1 [00:00<00:00, 94.00it/s]
# 0 files failed to parse, 1 successfully parsed

# %%
test_file[0][-1].rdmol_no_conformer

# %% [markdown]
# ## dsgdb9nsd_002924-8-.log

# %%
test_file = AutoParser(
    "../../tests/test_files/g16log/dsgdb9nsd_002924-8-.log",
    n_jobs=1,
    only_extract_structure=True,
    only_last_frame=True,
)
test_file[0][-1].rdmol
# Out:
# MolOP parsing with single thread: 100%|██████████| 1/1 [00:00<00:00, 113.37it/s]
# 0 files failed to parse, 1 successfully parsed

# %% [markdown]
# ## dsgdb9nsd_000763-2-.log

# %%
test_file = AutoParser(
    "../../tests/test_files/g16log/dsgdb9nsd_000763-2-.log",
    n_jobs=1,
    only_extract_structure=True,
    only_last_frame=True,
)
test_file[0][-1].rdmol
# Out:
# MolOP parsing with single thread: 100%|██████████| 1/1 [00:00<00:00, 152.56it/s]
# 0 files failed to parse, 1 successfully parsed

# %% [markdown]
# ## dsgdb9nsd_001232-4-.log

# %%
test_file = AutoParser(
    "../../tests/test_files/g16log/dsgdb9nsd_001232-4-.log",
    n_jobs=1,
    only_extract_structure=True,
    only_last_frame=True,
)
test_file[0][-1].rdmol
# Out:
# MolOP parsing with single thread: 100%|██████████| 1/1 [00:00<00:00, 125.44it/s]
# 0 files failed to parse, 1 successfully parsed

# %% [markdown]
# ## dsgdb9nsd_000180-9-.log

# %%
test_file = AutoParser(
    "../../tests/test_files/g16log/dsgdb9nsd_000180-9-.log",
    n_jobs=1,
)
test_file[0][-1].rdmol
# Out:
# MolOP parsing with single thread: 100%|██████████| 1/1 [00:00<00:00, 22.33it/s]
# 0 files failed to parse, 1 successfully parsed

# %% [markdown]
# ## TS_4cGKps_ll_ad_4-18_6-13_sp_g16.log

# %%
test_file = AutoParser(
    "../../tests/test_files/g16log/TS_4cGKps_ll_ad_4-18_6-13_sp_g16.log",
    n_jobs=1,
)
test_file[0][-1].rdmol
# Out:
# MolOP parsing with single thread: 100%|██████████| 1/1 [00:00<00:00, 321.03it/s]
# 0 files failed to parse, 1 successfully parsed

# %% [markdown]
# ## TS_ts_guess_FaFxyx_template_4-18_6-13_optts_conf_g16.log

# %%
test_file = AutoParser(
    "../../tests/test_files/g16log/TS_ts_guess_FaFxyx_template_4-18_6-13_optts_conf_g16.log",
    n_jobs=1,
    only_last_frame=True,
)
test_file[0][-1].rdmol
# Out:
# MolOP parsing with single thread: 100%|██████████| 1/1 [00:00<00:00, 15.50it/s]
# 0 files failed to parse, 1 successfully parsed

# %% [markdown]
# ## TS_4cGKps_ll_ad_4-18_6-13_optts_g16.log

# %%
test_file = AutoParser(
    "../../tests/test_files/g16log/TS_4cGKps_ll_ad_4-18_6-13_optts_g16.log",
    n_jobs=1,
    only_last_frame=True,
)
test_file[0][-1].rdmol
# Out:
# MolOP parsing with single thread: 100%|██████████| 1/1 [00:00<00:00, 26.82it/s]
# 0 files failed to parse, 1 successfully parsed

# %% [markdown]
# ## TS_Zy0fwX_ll_ad_14-19_15-16_optts_g16.log

# %%
test_file = AutoParser(
    "../../tests/test_files/g16log/TS_Zy0fwX_ll_ad_14-19_15-16_optts_g16.log",
    n_jobs=1,
)
test_file[0][-1].rdmol
# Out:
# MolOP parsing with single thread: 100%|██████████| 1/1 [00:00<00:00,  4.82it/s]
# 0 files failed to parse, 1 successfully parsed

# %% [markdown]
# ## irc.out

# %%
test_file = AutoParser(
    "../../tests/test_files/g16irc/irc.out",
    n_jobs=1,
)
test_file[0][-1].rdmol
# Out:
# MolOP parsing with single thread: 100%|██████████| 1/1 [00:00<00:00, 16.44it/s]
# 0 files failed to parse, 1 successfully parsed

# %% [markdown]
# ## 3_Sp.log

# %%
test_file = AutoParser(
    "../../tests/test_files/g16log/3_Sp.log",
    n_jobs=1,
)
test_file[0][-1].rdmol
# Out:
# MolOP parsing with single thread: 100%|██████████| 1/1 [00:00<00:00, 404.54it/s]
# 0 files failed to parse, 1 successfully parsed

# %% [markdown]
# ## 11_Opt.log

# %%
test_file = AutoParser(
    "../../tests/test_files/g16log/11_Opt.log",
    n_jobs=1,
)
test_file[0][-1].rdmol
# Out:
# MolOP parsing with single thread: 100%|██████████| 1/1 [00:00<00:00, 20.91it/s]
# 0 files failed to parse, 1 successfully parsed

# %% [markdown]
# ## dsgdb9nsd_003895.log

# %%
test_file = AutoParser(
    "../../tests/test_files/g16log/dsgdb9nsd_003895.log",
    n_jobs=1,
)
test_file[0][-1].rdmol
# Out:
# MolOP parsing with single thread: 100%|██████████| 1/1 [00:00<00:00, 45.69it/s]
# 0 files failed to parse, 1 successfully parsed

# %% [markdown]
# ## dsgdb9nsd_006075rearrange.log

# %%
test_file = AutoParser(
    "../../tests/test_files/g16log/dsgdb9nsd_006075rearrange.log",
    n_jobs=1,
)
test_file[0][-1].rdmol
# Out:
# MolOP parsing with single thread: 100%|██████████| 1/1 [00:00<00:00, 13.41it/s]
# 0 files failed to parse, 1 successfully parsed

# %% [markdown]
# ## dsgdb9nsd_130366.log

# %%
test_file = AutoParser(
    "../../tests/test_files/g16log/dsgdb9nsd_130366.log",
    n_jobs=1,
)
test_file[0][-1].rdmol
# Out:
# MolOP parsing with single thread: 100%|██████████| 1/1 [00:00<00:00, 28.09it/s]
# 0 files failed to parse, 1 successfully parsed

# %% [markdown]
# ## dsgdb9nsd_131200.log

# %%
test_file = AutoParser(
    "../../tests/test_files/g16log/dsgdb9nsd_131200.log",
    n_jobs=1,
)
test_file[0][-1].rdmol
# Out:
# MolOP parsing with single thread: 100%|██████████| 1/1 [00:00<00:00, 25.75it/s]
# 0 files failed to parse, 1 successfully parsed

# %% [markdown]
# ## dsgdb9nsd_132072.log

# %%
test_file = AutoParser(
    "../../tests/test_files/g16log/dsgdb9nsd_132072.log",
    n_jobs=1,
)
test_file[0][-1].rdmol
# Out:
# MolOP parsing with single thread: 100%|██████████| 1/1 [00:00<00:00, 25.44it/s]
# 0 files failed to parse, 1 successfully parsed

# %% [markdown]
# ## dsgdb9nsd_133826.log

# %%
test_file = AutoParser(
    "../../tests/test_files/g16log/dsgdb9nsd_133826.log",
    n_jobs=1,
)
test_file[0][-1].rdmol
# Out:
# MolOP parsing with single thread: 100%|██████████| 1/1 [00:00<00:00, 24.25it/s]
# 0 files failed to parse, 1 successfully parsed

# %% [markdown]
# ## dsgdb9nsd_133858.log

# %%
test_file = AutoParser(
    "../../tests/test_files/g16log/dsgdb9nsd_133858.log",
    n_jobs=1,
)
test_file[0][-1].rdmol
# Out:
# MolOP parsing with single thread: 100%|██████████| 1/1 [00:00<00:00, 21.53it/s]
# 0 files failed to parse, 1 successfully parsed

# %% [markdown]
# ## S_Ph_Ni_TS.gjf

# %%
test_file = AutoParser(
    "../../tests/test_files/g16gjf/S_Ph_Ni_TS.gjf",
    n_jobs=1,
)
test_file[0][-1].rdmol
# Out:
# MolOP parsing with single thread: 100%|██████████| 1/1 [00:00<00:00, 1902.18it/s]
# 0 files failed to parse, 1 successfully parsed

# %% [markdown]
# ## S_Ph_Ni_TS.log

# %%
test_file = AutoParser(
    "../../tests/test_files/g16log/S_Ph_Ni_TS.log",
    n_jobs=1,
)
test_file[0][-1].rdmol
# Out:
# MolOP parsing with single thread: 100%|██████████| 1/1 [00:00<00:00, 11.76it/s]
# 0 files failed to parse, 1 successfully parsed

# %% [markdown]
# ## test.gjf

# %%
test_file = AutoParser(
    "../../tests/test_files/g16gjf/test.gjf",
    n_jobs=1,
    charge=0,
    multiplicity=3,
)
test_file[0][-1].rdmol
# Out:
# MolOP parsing with single thread: 100%|██████████| 1/1 [00:00<00:00, 1890.18it/s]
# 0 files failed to parse, 1 successfully parsed

# %% [markdown]
# ## test.xyz

# %%
test_file = AutoParser(
    "../../tests/test_files/xyz/test.xyz",
    n_jobs=1,
    charge=0,
    multiplicity=3,
)
test_file[0][-1].rdmol
# Out:
# MolOP parsing with single thread: 100%|██████████| 1/1 [00:00<00:00, 1577.40it/s]
# 0 files failed to parse, 1 successfully parsed

# %% [markdown]
# ## dsgdb9nsd_009986.log

# %%
test_file = AutoParser(
    "../../tests/test_files/g16log/dsgdb9nsd_009986.log",
    n_jobs=1,
)
test_file[0][-1].rdmol
# Out:
# MolOP parsing with single thread: 100%|██████████| 1/1 [00:00<00:00, 29.19it/s]
# 0 files failed to parse, 1 successfully parsed

# %% [markdown]
# ## dsgdb9nsd_000001-3-.log

# %%
test_file = AutoParser(
    "../../tests/test_files/g16log/dsgdb9nsd_000001-3-.log",
    n_jobs=1,
)
test_file[0][-1].rdmol
# Out:
# MolOP parsing with single thread: 100%|██████████| 1/1 [00:00<00:00, 80.28it/s]
# 0 files failed to parse, 1 successfully parsed

# %% [markdown]
# ## xtb_6_3_2_opt.out
# Out file is the printout on screen of the xtb calculation.
# you can get it by:
#
# ```bash
# xtb ***.xyz > ***.out
# ```

# %%
test_file = AutoParser(
    "../../tests/test_files/xtbout/xtb_6_3_2_opt.out",
    n_jobs=1,
)
test_file[0][-1].rdmol
# Out:
# MolOP parsing with single thread: 100%|██████████| 1/1 [00:00<00:00, 131.76it/s]
# 0 files failed to parse, 1 successfully parsed
