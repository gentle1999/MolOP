# %% [markdown]
# # Structure recovery cases

# %%
from molop.io import AutoParser
from rdkit.Chem.Draw import IPythonConsole

IPythonConsole.drawOptions.addAtomIndices = True
IPythonConsole.molSize = 400, 400

# %% [markdown]
# ## molecule_0.log

# %%
test_file = AutoParser(
    "../../tests/test_files/g16log/molecule_0.log",
    n_jobs=1,
    only_extract_structure=True,
    only_last_frame=True,
)
test_file[0][-1].rdmol
# Out:
# MolOP parsing with single thread: 100%|██████████| 1/1 [00:00<00:00, 414.70it/s]
# 0 files failed to parse, 1 successfully parsed

# %% [markdown]
# ## dsgdb9nsd_131941-4+.log

# %%
test_file = AutoParser(
    "../../tests/test_files/g16log/dsgdb9nsd_131941-4+.log",
    n_jobs=1,
    only_extract_structure=True,
    only_last_frame=True,
)
test_file[0][-1].rdmol
# Out:
# MolOP parsing with single thread: 100%|██████████| 1/1 [00:00<00:00, 496.37it/s]
# 0 files failed to parse, 1 successfully parsed

# %% [markdown]
# ## RE_BOX-Anion-Real_Cu-III-Phenol_Major-Amide-Anion_From-IP_C-O-190_TS_Opt.log

# %%
test_file = AutoParser(
    "../../tests/test_files/g16log/RE_BOX-Anion-Real_Cu-III-Phenol_Major-Amide-Anion_From-IP_C-O-190_TS_Opt.log",
    n_jobs=1,
    only_extract_structure=True,
    only_last_frame=True,
)
test_file[0][-1].rdmol
# Out:
# MolOP parsing with single thread: 100%|██████████| 1/1 [00:00<00:00, 91.68it/s]
# 0 files failed to parse, 1 successfully parsed

# %% [markdown]
# ## add_1.fchk

# %%
test_file = AutoParser(
    "../../tests/test_files/g16fchk/add_1.fchk",
    n_jobs=1,
    only_extract_structure=True,
    only_last_frame=True,
)
test_file[0][-1].rdmol
# Out:
# MolOP parsing with single thread: 100%|██████████| 1/1 [00:00<00:00, 13.66it/s]
# 0 files failed to parse, 1 successfully parsed

# %% [markdown]
# ## add_0.fchk

# %%
test_file = AutoParser(
    "../../tests/test_files/g16fchk/add_0.fchk",
    n_jobs=1,
    only_extract_structure=True,
    only_last_frame=True,
)
test_file[0][-1].rdmol
# Out:
# MolOP parsing with single thread: 100%|██████████| 1/1 [00:00<00:00, 205.30it/s]
# 0 files failed to parse, 1 successfully parsed

# %% [markdown]
# ## dsgdb9nsd_000007-6.fchk

# %%
test_file = AutoParser(
    "../../tests/test_files/g16fchk/dsgdb9nsd_000007-6.fchk",
    n_jobs=1,
    only_extract_structure=True,
    only_last_frame=True,
)
test_file[0][-1].rdmol
# Out:
# MolOP parsing with single thread: 100%|██████████| 1/1 [00:00<00:00, 481.16it/s]
# 0 files failed to parse, 1 successfully parsed

# %% [markdown]
# ## dsgdb9nsd_000001-3.fchk

# %%
test_file = AutoParser(
    "../../tests/test_files/g16fchk/dsgdb9nsd_000001-3.fchk",
    n_jobs=1,
    only_extract_structure=True,
    only_last_frame=True,
)
test_file[0][-1].rdmol
# Out:
# MolOP parsing with single thread: 100%|██████████| 1/1 [00:00<00:00, 570.73it/s]
# 0 files failed to parse, 1 successfully parsed

# %% [markdown]
# ## dsgdb9nsd_000484-1+.log

# %%
test_file = AutoParser(
    "../../tests/test_files/g16log/dsgdb9nsd_000484-1+.log",
    n_jobs=1,
    only_extract_structure=True,
    only_last_frame=True,
)
test_file[0][-1].rdmol
# Out:
# MolOP parsing with single thread: 100%|██████████| 1/1 [00:00<00:00, 696.73it/s]
# 0 files failed to parse, 1 successfully parsed

# %% [markdown]
# ## dsgdb9nsd_000672-3+.log

# %%
test_file = AutoParser(
    "../../tests/test_files/g16log/dsgdb9nsd_000672-3+.log",
    n_jobs=1,
    only_extract_structure=True,
    only_last_frame=True,
)
test_file[0][-1].rdmol
# Out:
# MolOP parsing with single thread: 100%|██████████| 1/1 [00:00<00:00, 618.08it/s]
# 0 files failed to parse, 1 successfully parsed

# %% [markdown]
# ## dsgdb9nsd_000923-3+.log

# %%
test_file = AutoParser(
    "../../tests/test_files/g16log/dsgdb9nsd_000923-3+.log",
    n_jobs=1,
    only_extract_structure=True,
    only_last_frame=True,
)
test_file[0][-1].rdmol
# Out:
# MolOP parsing with single thread: 100%|██████████| 1/1 [00:00<00:00, 473.56it/s]
# 0 files failed to parse, 1 successfully parsed

# %% [markdown]
# ## dsgdb9nsd_003051-3.log

# %%
test_file = AutoParser(
    "../../tests/test_files/g16log/dsgdb9nsd_003051-3.log",
    n_jobs=1,
    only_extract_structure=True,
    only_last_frame=True,
)
test_file[0][-1].rdmol
# Out:
# MolOP parsing with single thread: 100%|██████████| 1/1 [00:00<00:00, 521.81it/s]
# 0 files failed to parse, 1 successfully parsed

# %% [markdown]
# ## dsgdb9nsd_000696-4.log

# %%
test_file = AutoParser(
    "../../tests/test_files/g16log/dsgdb9nsd_000696-4.log",
    n_jobs=1,
    only_extract_structure=True,
    only_last_frame=True,
)
test_file[0][-1].rdmol
# Out:
# MolOP parsing with single thread: 100%|██████████| 1/1 [00:00<00:00, 361.92it/s]
# 0 files failed to parse, 1 successfully parsed

# %% [markdown]
# ## dsgdb9nsd_004669-4.log

# %%
test_file = AutoParser(
    "../../tests/test_files/g16log/dsgdb9nsd_004669-4.log",
    n_jobs=1,
    only_extract_structure=True,
    only_last_frame=True,
)
test_file[0][-1].rdmol
# Out:
# MolOP parsing with single thread: 100%|██████████| 1/1 [00:00<00:00, 695.80it/s]
# 0 files failed to parse, 1 successfully parsed

# %% [markdown]
# ## dsgdb9nsd_131200-4-.log

# %%
test_file = AutoParser(
    "../../tests/test_files/g16log/dsgdb9nsd_131200-4-.log",
    n_jobs=1,
    only_extract_structure=True,
    only_last_frame=True,
)
test_file[0][-1].rdmol
# Out:
# MolOP parsing with single thread: 100%|██████████| 1/1 [00:00<00:00, 611.50it/s]
# 0 files failed to parse, 1 successfully parsed

# %% [markdown]
# ## dsgdb9nsd_000955-3.log

# %%
test_file = AutoParser(
    "../../tests/test_files/g16log/dsgdb9nsd_000955-3.log",
    n_jobs=1,
    only_extract_structure=True,
    only_last_frame=True,
)
test_file[0][-1].rdmol
# Out:
# MolOP parsing with single thread: 100%|██████████| 1/1 [00:00<00:00, 596.46it/s]
# 0 files failed to parse, 1 successfully parsed

# %%
test_file[0][-1].rdmol_no_conformer

# %% [markdown]
# ## r1_C2H3N3O_sp_g16.log

# %%
test_file = AutoParser(
    "../../tests/test_files/g16log/r1_C2H3N3O_sp_g16.log",
    n_jobs=1,
    only_extract_structure=True,
    only_last_frame=True,
)
test_file[0][-1].rdmol
# Out:
# MolOP parsing with single thread: 100%|██████████| 1/1 [00:00<00:00, 866.59it/s]
# 0 files failed to parse, 1 successfully parsed

# %% [markdown]
# ## r1_C8H9N3O2_sp_g16.log

# %%
test_file = AutoParser(
    "../../tests/test_files/g16log/r1_C8H9N3O2_sp_g16.log",
    n_jobs=1,
    only_extract_structure=True,
    only_last_frame=True,
)
test_file[0][-1].rdmol
# Out:
# MolOP parsing with single thread: 100%|██████████| 1/1 [00:00<00:00, 714.78it/s]
# 0 files failed to parse, 1 successfully parsed

# %% [markdown]
# ## dsgdb9nsd_004738-2.log

# %%
test_file = AutoParser(
    "../../tests/test_files/g16log/dsgdb9nsd_004738-2.log",
    n_jobs=1,
    only_extract_structure=True,
    only_last_frame=True,
)
test_file[0][-1].rdmol
# Out:
# MolOP parsing with single thread: 100%|██████████| 1/1 [00:00<00:00, 501.23it/s]
# 0 files failed to parse, 1 successfully parsed

# %% [markdown]
# ## dsgdb9nsd_004015-3-.log

# %%
test_file = AutoParser(
    "../../tests/test_files/g16log/dsgdb9nsd_004015-3-.log",
    n_jobs=1,
    only_extract_structure=True,
    only_last_frame=True,
)
test_file[0][-1].rdmol
# Out:
# MolOP parsing with single thread: 100%|██████████| 1/1 [00:00<00:00, 496.07it/s]
# 0 files failed to parse, 1 successfully parsed

# %% [markdown]
# ## dsgdb9nsd_000107-3-.log

# %%
test_file = AutoParser(
    "../../tests/test_files/g16log/dsgdb9nsd_000107-3-.log",
    n_jobs=1,
    only_extract_structure=True,
    only_last_frame=True,
)
test_file[0][-1].rdmol
# Out:
# MolOP parsing with single thread: 100%|██████████| 1/1 [00:00<00:00, 585.80it/s]
# 0 files failed to parse, 1 successfully parsed

# %% [markdown]
# ## dsgdb9nsd_004517-4-.log

# %%
test_file = AutoParser(
    "../../tests/test_files/g16log/dsgdb9nsd_004478-6-.log",
    n_jobs=1,
    only_extract_structure=True,
    only_last_frame=True,
)
test_file[0][-1].rdmol
# Out:
# MolOP parsing with single thread: 100%|██████████| 1/1 [00:00<00:00, 679.46it/s]
# 0 files failed to parse, 1 successfully parsed

# %%
test_file[0][-1].rdmol_no_conformer

# %% [markdown]
# ## dsgdb9nsd_004517-4-.log

# %%
test_file = AutoParser(
    "../../tests/test_files/g16log/dsgdb9nsd_004517-4-.log",
    n_jobs=1,
    only_extract_structure=True,
    only_last_frame=True,
)
test_file[0][-1].rdmol
# Out:
# MolOP parsing with single thread: 100%|██████████| 1/1 [00:00<00:00, 488.68it/s]
# 0 files failed to parse, 1 successfully parsed

# %% [markdown]
# ## dsgdb9nsd_000958-3-.log

# %%
test_file = AutoParser(
    "../../tests/test_files/g16log/dsgdb9nsd_000958-3-.log",
    n_jobs=1,
    only_extract_structure=True,
    only_last_frame=True,
)
test_file[0][-1].rdmol
# Out:
# MolOP parsing with single thread: 100%|██████████| 1/1 [00:00<00:00, 634.83it/s]
# 0 files failed to parse, 1 successfully parsed

# %%
test_file[0][-1].rdmol_no_conformer

# %% [markdown]
# ## dsgdb9nsd_002924-8-.log

# %%
test_file = AutoParser(
    "../../tests/test_files/g16log/dsgdb9nsd_002924-8-.log",
    n_jobs=1,
    only_extract_structure=True,
    only_last_frame=True,
)
test_file[0][-1].rdmol
# Out:
# MolOP parsing with single thread: 100%|██████████| 1/1 [00:00<00:00, 552.17it/s]
# 0 files failed to parse, 1 successfully parsed

# %% [markdown]
# ## dsgdb9nsd_000763-2-.log

# %%
test_file = AutoParser(
    "../../tests/test_files/g16log/dsgdb9nsd_000763-2-.log",
    n_jobs=1,
    only_extract_structure=True,
    only_last_frame=True,
)
test_file[0][-1].rdmol
# Out:
# MolOP parsing with single thread: 100%|██████████| 1/1 [00:00<00:00, 704.10it/s]
# 0 files failed to parse, 1 successfully parsed

# %% [markdown]
# ## dsgdb9nsd_001232-4-.log

# %%
test_file = AutoParser(
    "../../tests/test_files/g16log/dsgdb9nsd_001232-4-.log",
    n_jobs=1,
    only_extract_structure=True,
    only_last_frame=True,
)
test_file[0][-1].rdmol
# Out:
# MolOP parsing with single thread: 100%|██████████| 1/1 [00:00<00:00, 479.95it/s]
# 0 files failed to parse, 1 successfully parsed

# %% [markdown]
# ## dsgdb9nsd_000180-9-.log

# %%
test_file = AutoParser(
    "../../tests/test_files/g16log/dsgdb9nsd_000180-9-.log",
    n_jobs=1,
)
test_file[0][-1].rdmol
# Out:
# MolOP parsing with single thread: 100%|██████████| 1/1 [00:00<00:00, 25.81it/s]
# 0 files failed to parse, 1 successfully parsed

# %% [markdown]
# ## TS_4cGKps_ll_ad_4-18_6-13_sp_g16.log

# %%
test_file = AutoParser(
    "../../tests/test_files/g16log/TS_4cGKps_ll_ad_4-18_6-13_sp_g16.log",
    n_jobs=1,
)
test_file[0][-1].rdmol
# Out:
# MolOP parsing with single thread: 100%|██████████| 1/1 [00:00<00:00, 300.11it/s]
# 0 files failed to parse, 1 successfully parsed

# %% [markdown]
# ## TS_ts_guess_FaFxyx_template_4-18_6-13_optts_conf_g16.log

# %%
test_file = AutoParser(
    "../../tests/test_files/g16log/TS_ts_guess_FaFxyx_template_4-18_6-13_optts_conf_g16.log",
    n_jobs=1,
    only_last_frame=True,
)
test_file[0][-1].rdmol
# Out:
# MolOP parsing with single thread: 100%|██████████| 1/1 [00:00<00:00, 35.30it/s]
# 0 files failed to parse, 1 successfully parsed

# %% [markdown]
# ## TS_4cGKps_ll_ad_4-18_6-13_optts_g16.log

# %%
test_file = AutoParser(
    "../../tests/test_files/g16log/TS_4cGKps_ll_ad_4-18_6-13_optts_g16.log",
    n_jobs=1,
    only_last_frame=True,
)
test_file[0][-1].rdmol
# Out:
# MolOP parsing with single thread: 100%|██████████| 1/1 [00:00<00:00, 35.14it/s]
# 0 files failed to parse, 1 successfully parsed

# %% [markdown]
# ## TS_Zy0fwX_ll_ad_14-19_15-16_optts_g16.log

# %%
test_file = AutoParser(
    "../../tests/test_files/g16log/TS_Zy0fwX_ll_ad_14-19_15-16_optts_g16.log",
    n_jobs=1,
)
test_file[0][-1].rdmol
# Out:
# MolOP parsing with single thread: 100%|██████████| 1/1 [00:00<00:00,  5.77it/s]
# 0 files failed to parse, 1 successfully parsed

# %% [markdown]
# ## irc.out

# %%
test_file = AutoParser(
    "../../tests/test_files/g16irc/irc.out",
    n_jobs=1,
)
test_file[0][-1].rdmol
# Out:
# MolOP parsing with single thread: 100%|██████████| 1/1 [00:00<00:00, 20.40it/s]
# 0 files failed to parse, 1 successfully parsed

# %% [markdown]
# ## 3_Sp.log

# %%
test_file = AutoParser(
    "../../tests/test_files/g16log/3_Sp.log",
    n_jobs=1,
)
test_file[0][-1].rdmol
# Out:
# MolOP parsing with single thread: 100%|██████████| 1/1 [00:00<00:00, 343.68it/s]
# 0 files failed to parse, 1 successfully parsed

# %% [markdown]
# ## 11_Opt.log

# %%
test_file = AutoParser(
    "../../tests/test_files/g16log/11_Opt.log",
    n_jobs=1,
)
test_file[0][-1].rdmol
# Out:
# MolOP parsing with single thread: 100%|██████████| 1/1 [00:00<00:00, 20.87it/s]
# 0 files failed to parse, 1 successfully parsed

# %% [markdown]
# ## dsgdb9nsd_003895.log

# %%
test_file = AutoParser(
    "../../tests/test_files/g16log/dsgdb9nsd_003895.log",
    n_jobs=1,
)
test_file[0][-1].rdmol
# Out:
# MolOP parsing with single thread: 100%|██████████| 1/1 [00:00<00:00, 69.69it/s]
# 0 files failed to parse, 1 successfully parsed

# %% [markdown]
# ## dsgdb9nsd_006075rearrange.log

# %%
test_file = AutoParser(
    "../../tests/test_files/g16log/dsgdb9nsd_006075rearrange.log",
    n_jobs=1,
)
test_file[0][-1].rdmol
# Out:
# MolOP parsing with single thread: 100%|██████████| 1/1 [00:00<00:00, 15.02it/s]
# 0 files failed to parse, 1 successfully parsed

# %% [markdown]
# ## dsgdb9nsd_130366.log

# %%
test_file = AutoParser(
    "../../tests/test_files/g16log/dsgdb9nsd_130366.log",
    n_jobs=1,
)
test_file[0][-1].rdmol
# Out:
# MolOP parsing with single thread: 100%|██████████| 1/1 [00:00<00:00, 40.61it/s]
# 0 files failed to parse, 1 successfully parsed

# %% [markdown]
# ## dsgdb9nsd_131200.log

# %%
test_file = AutoParser(
    "../../tests/test_files/g16log/dsgdb9nsd_131200.log",
    n_jobs=1,
)
test_file[0][-1].rdmol
# Out:
# MolOP parsing with single thread: 100%|██████████| 1/1 [00:00<00:00, 38.13it/s]
# 0 files failed to parse, 1 successfully parsed

# %% [markdown]
# ## dsgdb9nsd_132072.log

# %%
test_file = AutoParser(
    "../../tests/test_files/g16log/dsgdb9nsd_132072.log",
    n_jobs=1,
)
test_file[0][-1].rdmol
# Out:
# MolOP parsing with single thread: 100%|██████████| 1/1 [00:00<00:00, 34.68it/s]
# 0 files failed to parse, 1 successfully parsed

# %% [markdown]
# ## dsgdb9nsd_133826.log

# %%
test_file = AutoParser(
    "../../tests/test_files/g16log/dsgdb9nsd_133826.log",
    n_jobs=1,
)
test_file[0][-1].rdmol
# Out:
# MolOP parsing with single thread: 100%|██████████| 1/1 [00:00<00:00, 33.78it/s]
# 0 files failed to parse, 1 successfully parsed

# %% [markdown]
# ## dsgdb9nsd_133858.log

# %%
test_file = AutoParser(
    "../../tests/test_files/g16log/dsgdb9nsd_133858.log",
    n_jobs=1,
)
test_file[0][-1].rdmol
# Out:
# MolOP parsing with single thread: 100%|██████████| 1/1 [00:00<00:00, 29.13it/s]
# 0 files failed to parse, 1 successfully parsed

# %% [markdown]
# ## S_Ph_Ni_TS.gjf

# %%
test_file = AutoParser(
    "../../tests/test_files/g16gjf/S_Ph_Ni_TS.gjf",
    n_jobs=1,
)
test_file[0][-1].rdmol
# Out:
# MolOP parsing with single thread: 100%|██████████| 1/1 [00:00<00:00, 1437.39it/s]
# 0 files failed to parse, 1 successfully parsed

# %% [markdown]
# ## S_Ph_Ni_TS.log

# %%
test_file = AutoParser(
    "../../tests/test_files/g16log/S_Ph_Ni_TS.log",
    n_jobs=1,
)
test_file[0][-1].rdmol
# Out:
# MolOP parsing with single thread: 100%|██████████| 1/1 [00:00<00:00,  9.42it/s]
# 0 files failed to parse, 1 successfully parsed

# %% [markdown]
# ## test.gjf

# %%
test_file = AutoParser(
    "../../tests/test_files/g16gjf/test.gjf",
    n_jobs=1,
    charge=0,
    multiplicity=3,
)
test_file[0][-1].rdmol
# Out:
# MolOP parsing with single thread: 100%|██████████| 1/1 [00:00<00:00, 1761.57it/s]
# 0 files failed to parse, 1 successfully parsed

# %% [markdown]
# ## test.xyz

# %%
test_file = AutoParser(
    "../../tests/test_files/xyz/test.xyz",
    n_jobs=1,
    charge=0,
    multiplicity=3,
)
test_file[0][-1].rdmol
# Out:
# MolOP parsing with single thread: 100%|██████████| 1/1 [00:00<00:00, 1394.38it/s]
# 0 files failed to parse, 1 successfully parsed

# %% [markdown]
# ## dsgdb9nsd_009986.log

# %%
test_file = AutoParser(
    "../../tests/test_files/g16log/dsgdb9nsd_009986.log",
    n_jobs=1,
)
test_file[0][-1].rdmol
# Out:
# MolOP parsing with single thread: 100%|██████████| 1/1 [00:00<00:00, 35.52it/s]
# 0 files failed to parse, 1 successfully parsed

# %% [markdown]
# ## dsgdb9nsd_000001-3-.log

# %%
test_file = AutoParser(
    "../../tests/test_files/g16log/dsgdb9nsd_000001-3-.log",
    n_jobs=1,
)
test_file[0][-1].rdmol
# Out:
# MolOP parsing with single thread: 100%|██████████| 1/1 [00:00<00:00, 87.49it/s]
# 0 files failed to parse, 1 successfully parsed

# %% [markdown]
# ## xtb_6_3_2_opt.out
# Out file is the printout on screen of the xtb calculation.
# you can get it by:
#
# ```bash
# xtb ***.xyz > ***.out
# ```

# %%
test_file = AutoParser(
    "../../tests/test_files/xtbout/xtb_6_3_2_opt.out",
    n_jobs=1,
)
test_file[0][-1].rdmol
# Out:
# MolOP parsing with single thread: 100%|██████████| 1/1 [00:00<00:00, 110.96it/s]
# 0 files failed to parse, 1 successfully parsed
